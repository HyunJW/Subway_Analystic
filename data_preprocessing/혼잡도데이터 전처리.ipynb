# %%
import pandas as pd
import numpy as np

# %%
df_1=pd.read_csv('./서울교통공사_혼잡도_20171231.csv', encoding='cp949')
df_2=pd.read_csv('./서울교통공사_혼잡도_20191231.csv', encoding='cp949')
df_3=pd.read_csv('./서울교통공사_혼잡도_20211231.csv', encoding='cp949')

# %%
# 컬럼: 조사일자, 호선('~호선'), 역명, 방향, 5시30분(%)~23시30분(%)로 변경
df_1.drop(columns=['호선','24:00~ (%)','24:30~ (%)'], inplace=True)
df_2.drop(columns=['호선','24시00분', '24시30분'], inplace=True)
df_3.drop(columns=['연번','호선'], inplace=True)

# %%
# 호선 열 재생성
df_1['호선']=0
df_2['호선']=0
df_3['호선']=0
for i in range(0, len(df_1)):
    if len(str(df_1.iloc[i]['역번호']))==3:
        df_1.loc[i, '호선']=str(df_1.iloc[i]['역번호'])[0]+'호선'
    else:
        df_1.loc[i, '호선']=str(df_1.iloc[i]['역번호'])[1]+'호선'
        
for i in range(0, len(df_2)):
    if len(str(df_2.iloc[i]['역번호']))==3:
        df_2.loc[i, '호선']=str(df_2.iloc[i]['역번호'])[0]+'호선'
    else:
        df_2.loc[i, '호선']=str(df_2.iloc[i]['역번호'])[1]+'호선'
        
for i in range(0, len(df_3)):
    if len(str(df_3.iloc[i]['역번호']))==3:
        df_3.loc[i, '호선']=str(df_3.iloc[i]['역번호'])[0]+'호선'
    else:
        df_3.loc[i, '호선']=str(df_3.iloc[i]['역번호'])[1]+'호선'

# 역번호 열 제거
df_1.drop(columns=['역번호'], inplace=True)
df_2.drop(columns=['역번호'], inplace=True)
df_3.drop(columns=['역번호'], inplace=True)

# %%
# 조사연도 추가
df_1['조사연도']=2017
df_2['조사연도']=2019
df_3['조사연도']=2021

# %%
# 칼럼 이름 통합
df_1.columns=['조사일자', '역명', '방향', '5시30분~ (%)', '6시00분~ (%)', '6시30분~ (%)',
       '7시00분~ (%)', '7시30분~ (%)', '8시00분~ (%)', '8시30분~ (%)', '9시00분~ (%)',
       '9시30분~ (%)', '10시00분~ (%)', '10시30분~ (%)', '11시00분~ (%)', '11시30분~ (%)',
       '12시00분~ (%)', '12시30분~ (%)', '13시00분~ (%)', '13시30분~ (%)', '14시00분~ (%)',
       '14시30분~ (%)', '15시00분~ (%)', '15시30분~ (%)', '16시00분~ (%)', '16시30분~ (%)',
       '17시00분~ (%)', '17시30분~ (%)', '18시00분~ (%)', '18시30분~ (%)', '19시00분~ (%)',
       '19시30분~ (%)', '20시00분~ (%)', '20시30분~ (%)', '21시00분~ (%)', '21시30분~ (%)',
       '22시00분~ (%)', '22시30분~ (%)', '23시00분~ (%)', '23시30분~ (%)', '호선','조사연도']
df_2.columns=['조사일자', '역명', '방향', '5시30분~ (%)', '6시00분~ (%)', '6시30분~ (%)',
       '7시00분~ (%)', '7시30분~ (%)', '8시00분~ (%)', '8시30분~ (%)', '9시00분~ (%)',
       '9시30분~ (%)', '10시00분~ (%)', '10시30분~ (%)', '11시00분~ (%)', '11시30분~ (%)',
       '12시00분~ (%)', '12시30분~ (%)', '13시00분~ (%)', '13시30분~ (%)', '14시00분~ (%)',
       '14시30분~ (%)', '15시00분~ (%)', '15시30분~ (%)', '16시00분~ (%)', '16시30분~ (%)',
       '17시00분~ (%)', '17시30분~ (%)', '18시00분~ (%)', '18시30분~ (%)', '19시00분~ (%)',
       '19시30분~ (%)', '20시00분~ (%)', '20시30분~ (%)', '21시00분~ (%)', '21시30분~ (%)',
       '22시00분~ (%)', '22시30분~ (%)', '23시00분~ (%)', '23시30분~ (%)', '호선','조사연도']
df_3.columns=['조사일자', '역명', '방향', '5시30분~ (%)', '6시00분~ (%)', '6시30분~ (%)',
       '7시00분~ (%)', '7시30분~ (%)', '8시00분~ (%)', '8시30분~ (%)', '9시00분~ (%)',
       '9시30분~ (%)', '10시00분~ (%)', '10시30분~ (%)', '11시00분~ (%)', '11시30분~ (%)',
       '12시00분~ (%)', '12시30분~ (%)', '13시00분~ (%)', '13시30분~ (%)', '14시00분~ (%)',
       '14시30분~ (%)', '15시00분~ (%)', '15시30분~ (%)', '16시00분~ (%)', '16시30분~ (%)',
       '17시00분~ (%)', '17시30분~ (%)', '18시00분~ (%)', '18시30분~ (%)', '19시00분~ (%)',
       '19시30분~ (%)', '20시00분~ (%)', '20시30분~ (%)', '21시00분~ (%)', '21시30분~ (%)',
       '22시00분~ (%)', '22시30분~ (%)', '23시00분~ (%)', '23시30분~ (%)', '호선','조사연도']

# %%
# 컬럼 순서 교체
df_1=df_1[['조사연도', '조사일자', '호선', '역명', '방향', '5시30분~ (%)', '6시00분~ (%)', '6시30분~ (%)',
       '7시00분~ (%)', '7시30분~ (%)', '8시00분~ (%)', '8시30분~ (%)', '9시00분~ (%)',
       '9시30분~ (%)', '10시00분~ (%)', '10시30분~ (%)', '11시00분~ (%)', '11시30분~ (%)',
       '12시00분~ (%)', '12시30분~ (%)', '13시00분~ (%)', '13시30분~ (%)', '14시00분~ (%)',
       '14시30분~ (%)', '15시00분~ (%)', '15시30분~ (%)', '16시00분~ (%)', '16시30분~ (%)',
       '17시00분~ (%)', '17시30분~ (%)', '18시00분~ (%)', '18시30분~ (%)', '19시00분~ (%)',
       '19시30분~ (%)', '20시00분~ (%)', '20시30분~ (%)', '21시00분~ (%)', '21시30분~ (%)',
       '22시00분~ (%)', '22시30분~ (%)', '23시00분~ (%)', '23시30분~ (%)']]
df_2=df_2[['조사연도','조사일자', '호선', '역명', '방향', '5시30분~ (%)', '6시00분~ (%)', '6시30분~ (%)',
       '7시00분~ (%)', '7시30분~ (%)', '8시00분~ (%)', '8시30분~ (%)', '9시00분~ (%)',
       '9시30분~ (%)', '10시00분~ (%)', '10시30분~ (%)', '11시00분~ (%)', '11시30분~ (%)',
       '12시00분~ (%)', '12시30분~ (%)', '13시00분~ (%)', '13시30분~ (%)', '14시00분~ (%)',
       '14시30분~ (%)', '15시00분~ (%)', '15시30분~ (%)', '16시00분~ (%)', '16시30분~ (%)',
       '17시00분~ (%)', '17시30분~ (%)', '18시00분~ (%)', '18시30분~ (%)', '19시00분~ (%)',
       '19시30분~ (%)', '20시00분~ (%)', '20시30분~ (%)', '21시00분~ (%)', '21시30분~ (%)',
       '22시00분~ (%)', '22시30분~ (%)', '23시00분~ (%)', '23시30분~ (%)']]
df_3=df_3[['조사연도','조사일자', '호선', '역명', '방향', '5시30분~ (%)', '6시00분~ (%)', '6시30분~ (%)',
       '7시00분~ (%)', '7시30분~ (%)', '8시00분~ (%)', '8시30분~ (%)', '9시00분~ (%)',
       '9시30분~ (%)', '10시00분~ (%)', '10시30분~ (%)', '11시00분~ (%)', '11시30분~ (%)',
       '12시00분~ (%)', '12시30분~ (%)', '13시00분~ (%)', '13시30분~ (%)', '14시00분~ (%)',
       '14시30분~ (%)', '15시00분~ (%)', '15시30분~ (%)', '16시00분~ (%)', '16시30분~ (%)',
       '17시00분~ (%)', '17시30분~ (%)', '18시00분~ (%)', '18시30분~ (%)', '19시00분~ (%)',
       '19시30분~ (%)', '20시00분~ (%)', '20시30분~ (%)', '21시00분~ (%)', '21시30분~ (%)',
       '22시00분~ (%)', '22시30분~ (%)', '23시00분~ (%)', '23시30분~ (%)']]

# %%
# 오류 데이터 변경
df_1.replace('0호선','5호선', inplace=True)

# %%
# 데이터 결합(2017 평일 1~8호선, 2017 토요일 1~8호선, 2017 1~8호선 일요일, 2019 ~~ , 2021~~ 순서)
df_1.sort_values(by=['조사일자','호선','역명'], axis=0, ascending=True, inplace=True)
df_2.sort_values(by=['조사일자','호선','역명'], axis=0, ascending=True, inplace=True)
df_3.sort_values(by=['조사일자','호선','역명'], axis=0, ascending=True, inplace=True)
df_conf=pd.concat([df_1,df_2,df_3], axis=0)

# %%
df_conf.reset_index(drop=True, inplace=True)

# %%
# 날짜별 평일/주말 구분
for i in range(0, len(df_conf)):
    if df_conf['조사일자'].iloc[i] in ['토요일','일요일']:
        df_conf.loc[i,'조사일자'] = '주말'

# %%
df_conf.replace(' ', '0.0', inplace=True)

# %%
df_conf.iloc[:,5:]=df_conf.iloc[:,5:].astype(float)

# %%
# 30분 단위 혼잡도 -> 1시간 단위 혼잡도
for i in range(6,41,2):
    df_conf=pd.concat([df_conf,df_conf.iloc[:,i:i+2].astype(float).mean(axis=1)], axis=1)

# %%
df_conf.drop(columns=df_conf.columns[6:42], inplace=True)

# %%
df_conf.columns=[['조사연도','조사일자','호선','역명','방향',
                  '06시 이전', '06~07', '07~08',
       '08~09', '09~10', '10~11', '11~12', '12~13', '13~14',
       '14~15', '15~16', '16~17', '17~18', '18~19', '19~20',
       '20~21', '21~22', '22~23', '23시 이후']]

# %%
df_conf = pd.read_csv('congestion.csv')

# %%
df_conf['역명'] = df_conf['역명'].str.split('(').str[0]

# %%
df_conf[df_conf['역명']=='t']
# Out:
#       조사연도 조사일자   호선  역명  방향  06시 이전  06~07  07~08  08~09  09~10  ...  14~15  \
# 246   2017   주말  5호선  강동  상선     8.9   8.80  14.50  21.25  25.45  ...  36.50
# 247   2017   주말  5호선  강동  하선     3.3   8.95   9.00  13.25  24.10  ...  25.80
# 248   2017   주말  5호선  강동  하선     2.2   4.55   4.70   6.30   6.25  ...  11.80
# 802   2017   주말  5호선  강동  상선    13.6  13.50  25.05  34.70  39.25  ...  44.50
# 803   2017   주말  5호선  강동  하선     4.5  13.10  19.95  25.05  26.55  ...  29.25
# 804   2017   주말  5호선  강동  하선     3.9   8.85   7.75   9.55   8.60  ...  16.55
# 1358  2017   평일  5호선  강동  상선    18.0  26.80  60.20  69.85  56.00  ...  27.15
# 1359  2017   평일  5호선  강동  하선     4.9  11.10  27.15  57.65  18.85  ...  24.45
# 1360  2017   평일  5호선  강동  하선     3.6   7.50   8.30  12.60   6.85  ...  13.75
# 1910  2019   주말  5호선  강동  상선     7.7   8.40  12.30  18.30  25.70  ...  30.50
# 1911  2019   주말  5호선  강동  하선     1.8   4.60   4.65   6.20   7.05  ...  13.15
# 2466  2019   주말  5호선  강동  상선    13.3  12.15  19.10  30.40  35.65  ...  40.15
# 2467  2019   주말  5호선  강동  하선     3.3   9.70   6.55  10.25  11.85  ...  16.95
# 3022  2019   평일  5호선  강동  상선    16.9  25.95  49.85  64.35  53.55  ...  25.30
# 3023  2019   평일  5호선  강동  하선     2.6   8.20   6.50  13.10   7.45  ...  15.85
# 3578  2021   주말  5호선  강동  상선     8.8   7.90  11.45  18.15  25.05  ...  27.40
# 3579  2021   주말  5호선  강동  하선     2.3   4.55   4.80   6.70   9.00  ...  13.40
# 4146  2021   주말  5호선  강동  상선    14.4  13.75  20.15  29.45  34.90  ...  35.25
# 4147  2021   주말  5호선  강동  하선     3.7   7.55   7.95  12.05  12.05  ...  18.40
# 4714  2021   평일  5호선  강동  상선    17.5  31.95  51.20  73.55  48.55  ...  26.95
# 4715  2021   평일  5호선  강동  하선     3.1   8.10  10.55  18.10   9.40  ...  22.20
#
#       15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23시 이후
# 246   32.40  30.60  27.00  21.15  15.80  14.05  14.90  12.40    5.90
# 247   24.65  27.70  33.55  29.30  24.45  19.20  17.15  16.10   14.25
# 248   14.00  15.90  17.85  17.65  15.40  12.25  13.00  11.65    8.85
# 802   42.85  48.55  47.60  33.40  22.15  16.80  20.80  17.25    9.70
# 803   34.80  40.35  47.40  37.85  27.35  22.95  22.90  24.30   24.55
# 804   19.05  20.70  25.20  21.70  18.60  16.05  16.50  17.00   16.10
# 1358  27.35  33.80  39.70  37.00  31.05  19.95  20.60  20.35   15.30
# 1359  27.90  33.55  24.95  42.50  35.55  31.80  31.50  34.85   25.05
# 1360  16.45  20.05  20.05  33.40  28.85  27.90  24.25  23.85   20.10
# 1910  27.30  27.70  23.50  18.15  12.50  15.65  12.20  33.75    5.95
# 1911  15.00  16.10  16.75  16.95  14.00  14.35  10.30  11.25    7.70
# 2466  37.55  41.75  41.45  26.75  18.00  14.00  17.20  26.15   11.10
# 2467  18.80  23.20  25.20  23.25  18.25  15.40  16.60  16.50   15.30
# 3022  25.95  32.90  38.85  33.85  24.80  17.10  17.20  17.55   13.15
# 3023  17.05  23.05  20.40  36.95  28.70  26.65  23.55  23.40   18.60
# 3578  24.35  26.95  25.80  19.35  15.20  12.15   9.95   9.75    4.00
# 3579  16.70  22.75  16.35  23.20  17.05  14.40  17.15  13.15    9.60
# 4146  32.65  42.70  39.20  26.95  17.50  15.20  13.25  12.80    9.85
# 4147  24.60  23.70  25.20  27.10  23.60  20.50  18.75  19.55   15.80
# 4714  28.90  35.60  29.80  41.15  23.40  18.30  14.80  16.60    7.70
# 4715  23.10  23.15  30.60  46.25  43.80  28.65  28.40  26.55   18.40
#
# [21 rows x 24 columns]

# %%
df_conf.to_csv('congestion.csv', index=False)
