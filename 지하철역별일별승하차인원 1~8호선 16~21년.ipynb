# %%
import pandas as pd

# %%
df_16=pd.read_csv('./서울교통공사_1_8호선일별역별시간대별승하차인원_2016년.csv', encoding='cp949')
df_17=pd.read_csv('./서울교통공사_1_8호선일별역별시간대별승하차인원_2017년.csv', encoding='cp949')
df_18=pd.read_csv('./서울교통공사_1_8호선일별역별시간대별승하차인원_2018년.csv', encoding='cp949')
df_19=pd.read_csv('./서울교통공사_1_8호선일별역별시간대별승하차인원_2019년.csv', encoding='cp949')
df_20=pd.read_csv('./서울교통공사_1_8호선일별역별시간대별승하차인원_2020년.csv', encoding='cp949')
df_21=pd.read_csv('./서울교통공사_1_8호선일별역별시간대별승하차인원_2021년.csv', encoding='cp949')

# %%
df_16['역번호'] = df_16['역번호'].astype(str)
df_16['역번호'] = df_16['역번호'].apply(lambda x : x[0] if len(x) == 3 else x[1])

# %%
df_16=df_16.drop(['월'], axis=1)

# %%
df_16.rename(columns={'역번호':'호선'}, inplace=True)

# %%
df_16
# Out:
#                 날짜 호선        역명  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0       2016-01-01  1  서울역(150)  승차    469    339    584   1144   1723   2087
# 1       2016-01-01  1  서울역(150)  하차    342   1637   1753   1856   2438   2425
# 2       2016-01-01  1   시청(151)  승차    103    127    110    191    298    582
# 3       2016-01-01  1   시청(151)  하차     68    306    554    939    689    665
# 4       2016-01-01  1   종각(152)  승차    702    341    234    296    335    419
# ...            ... ..       ...  ..    ...    ...    ...    ...    ...    ...
# 201295  2016-12-31  8        신흥  하차     23     62     77    114    223    150
# 201296  2016-12-31  8        수진  승차     85    119    202    291    327    283
# 201297  2016-12-31  8        수진  하차     37     71     62    137    148    129
# 201298  2016-12-31  8     모란(8)  승차     45     57    115    155    152    175
# 201299  2016-12-31  8     모란(8)  하차    114     56     73    104    134    135
#
# ...

# %%
df_17['역번호'] = df_17['역번호'].astype(str)
df_17['역번호'] = df_17['역번호'].apply(lambda x : x[0] if len(x) == 3 else x[1])
df_17.rename(columns={'역번호':'호선'}, inplace=True)

# %%
df_18['호선']=df_18['호선'].apply(lambda x: x[0])
df_18.drop(['역번호'], axis=1, inplace=True)

# %%
df_19['호선']=df_19['호선'].apply(lambda x: x[0])
df_19.drop(['역번호'], axis=1, inplace=True)

# %%
df_20['호선']=df_20['호선'].apply(lambda x: x[0])
df_20.drop(['역번호'], axis=1, inplace=True)

# %%
df_21.drop(['역번호'], axis=1, inplace=True)

# %%
df_21.drop(['합 계'], axis=1, inplace=True)

# %%
df_16.columns
# Out:
# Index(['날짜', '호선', '역명', '구분', '05~06', '06~07', '07~08', '08~09', '09~10',
#        '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18',
#        '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '24~'],
#       dtype='object')

# %%
df_16_24=df_16[['23~24','24~']]
df_16['~23']=df_16_24.sum(axis=1)
df_16.drop(['23~24','24~'], axis=1, inplace=True)
df_16
# Out:
#                 날짜 호선        역명  구분  05~06  06~07  07~08  08~09  09~10  10~11  \
# 0       2016-01-01  1  서울역(150)  승차    469    339    584   1144   1723   2087
# 1       2016-01-01  1  서울역(150)  하차    342   1637   1753   1856   2438   2425
# 2       2016-01-01  1   시청(151)  승차    103    127    110    191    298    582
# 3       2016-01-01  1   시청(151)  하차     68    306    554    939    689    665
# 4       2016-01-01  1   종각(152)  승차    702    341    234    296    335    419
# ...            ... ..       ...  ..    ...    ...    ...    ...    ...    ...
# 201295  2016-12-31  8        신흥  하차     23     62     77    114    223    150
# 201296  2016-12-31  8        수진  승차     85    119    202    291    327    283
# 201297  2016-12-31  8        수진  하차     37     71     62    137    148    129
# 201298  2016-12-31  8     모란(8)  승차     45     57    115    155    152    175
# 201299  2016-12-31  8     모란(8)  하차    114     56     73    104    134    135
#
# ...

# %%
df_17_24=df_17[['23~24','00 ~ 01']]
df_17['~23']=df_17_24.sum(axis=1)
df_17.drop(['23~24','00 ~ 01'], axis=1, inplace=True)
df_17
# Out:
#                 날짜 호선   역명  구분  05~06  06~07  07~08  08~09  09~10  10~11  ...  \
# 0       2017-01-01  1  서울역  승차    470    286    397    786   1421   1459  ...
# 1       2017-01-01  1  서울역  하차    278    880    859    964   1407   1622  ...
# 2       2017-01-01  1   시청  승차    204    105    112    162    288    396  ...
# 3       2017-01-01  1   시청  하차     73    203    314    483    669    611  ...
# 4       2017-01-01  1   종각  승차    791    390    245    270    323    482  ...
# ...            ... ..  ...  ..    ...    ...    ...    ...    ...    ...  ...
# 200745  2017-12-31  8   신흥  하차      9     49     38     53     97    113  ...
# 200746  2017-12-31  8   수진  승차     42     76    130    216    274    258  ...
# 200747  2017-12-31  8   수진  하차      8     68     76     88    150    206  ...
# 200748  2017-12-31  8   모란  승차     29     36     74     87    149    175  ...
# 200749  2017-12-31  8   모란  하차      5     55     36     50     81     84  ...
#
# ...

# %%
df_18_24=df_18[['23 ~ 24','00 ~ 01']]
df_18['~23']=df_18_24.sum(axis=1)
df_18.drop(['23 ~ 24','00 ~ 01'], axis=1, inplace=True)
df_18
# Out:
#                 날짜 호선   역명  구분  05 ~ 06  06 ~ 07  07 ~ 08  08 ~ 09  09 ~ 10  \
# 0       2018-01-01  1  서울역  승차      373      318      365      785     1047
# 1       2018-01-01  1  서울역  하차      205     1040      872      984     1650
# 2       2018-01-01  1   시청  승차       87      105      124      197      291
# 3       2018-01-01  1   시청  하차       47      294      497     1017      673
# 4       2018-01-01  1   종각  승차      604      399      191      250      370
# ...            ... ..  ...  ..      ...      ...      ...      ...      ...
# 200745  2018-12-31  8   신흥  하차       20       83       92      194      148
# 200746  2018-12-31  8   수진  승차       91      208      467      652      390
# 200747  2018-12-31  8   수진  하차       18       91      136      356      214
# 200748  2018-12-31  8   모란  승차       55       84      284      425      202
# 200749  2018-12-31  8   모란  하차       15       87      133      329      194
#
# ...

# %%
df_19_24=df_19[['23 ~ 24','24시 이후']]
df_19['~23']=df_19_24.sum(axis=1)
df_19.drop(['23 ~ 24','24시 이후'], axis=1, inplace=True)
df_19
# Out:
#                 날짜 호선   역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  09 ~ 10  \
# 0       2019-01-01  1  서울역  승차     348      321      348      741      940
# 1       2019-01-01  1  서울역  하차     222      821      808      961     1472
# 2       2019-01-01  1   시청  승차      87       98      143      206      280
# 3       2019-01-01  1   시청  하차      48      237      323      571      577
# 4       2019-01-01  1   종각  승차     669      318      217      203      333
# ...            ... ..  ...  ..     ...      ...      ...      ...      ...
# 200799  2019-12-31  8   신흥  하차      20       87       86      243      208
# 200800  2019-12-31  8   수진  승차     111      224      542      813      436
# 200801  2019-12-31  8   수진  하차      27       97      115      433      259
# 200802  2019-12-31  8   모란  승차      73       95      342      482      253
# 200803  2019-12-31  8   모란  하차      15       99      140      386      189
#
# ...

# %%
df_16.columns=['날짜', '호선', '역명', '구분', '~06', '06~07', '07~08', '08~09', '09~10',
       '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18',
       '18~19', '19~20', '20~21', '21~22', '22~23', '23~']

# %%
df_17.columns=['날짜', '호선', '역명', '구분', '~06', '06~07', '07~08', '08~09', '09~10',
       '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18',
       '18~19', '19~20', '20~21', '21~22', '22~23', '23~']

# %%
df_18.columns=['날짜', '호선', '역명', '구분', '~06', '06~07', '07~08', '08~09', '09~10',
       '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18',
       '18~19', '19~20', '20~21', '21~22', '22~23', '23~']

# %%
df_19.columns=['날짜', '호선', '역명', '구분', '~06', '06~07', '07~08', '08~09', '09~10',
       '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18',
       '18~19', '19~20', '20~21', '21~22', '22~23', '23~']

# %%
df_20.columns=['날짜', '호선', '역명', '구분', '~06', '06~07', '07~08', '08~09', '09~10',
       '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18',
       '18~19', '19~20', '20~21', '21~22', '22~23', '23~']

# %%
df_21.drop(['연번'], axis=1, inplace=True)

# %%
df_21.columns=['날짜', '호선', '역명', '구분', '~06', '06~07', '07~08', '08~09', '09~10',
       '10~11', '11~12', '12~13', '13~14', '14~15', '15~16', '16~17', '17~18',
       '18~19', '19~20', '20~21', '21~22', '22~23', '23~']

# %%
df_21
# Out:
#                 날짜  호선   역명  구분  ~06  06~07  07~08  08~09  09~10  10~11  ...  \
# 0       2021-01-01   1  서울역  승차   86    111    157    306    333    416  ...
# 1       2021-01-01   1  서울역  하차   85    355    438    592    841    747  ...
# 2       2021-01-01   1   시청  승차   43     45     75    111     95     76  ...
# 3       2021-01-01   1   시청  하차   40    145    176    312    223    189  ...
# 4       2021-01-01   1   종각  승차   49     59     89    126    125    113  ...
# ...            ...  ..  ...  ..  ...    ...    ...    ...    ...    ...  ...
# 204369  2021-12-31   8   수진  하차   25     75     96    340    180    179  ...
# 204370  2021-12-31   8   모란  승차   44    102    279    391    187    178  ...
# 204371  2021-12-31   8   모란  하차   20     96    120    311    132    143  ...
# 204372  2021-12-31   8  남위례  승차   20     83    279    347    138    186  ...
# 204373  2021-12-31   8  남위례  하차   10     41    119    375    147     76  ...
#
# ...

# %%
df=df_16.append(df_17)
df=df.append(df_18)
df=df.append(df_19)
df=df.append(df_20)
df=df.append(df_21)
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11020\1836826533.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df_16.append(df_17)
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11020\1836826533.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df_18)
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11020\1836826533.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df_19)
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_11020\1836826533.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df_20)
# ...

# %%
df
# Out:
#                 날짜 호선        역명  구분  ~06  06~07  07~08  08~09  09~10  10~11  \
# 0       2016-01-01  1  서울역(150)  승차  469    339    584   1144   1723   2087
# 1       2016-01-01  1  서울역(150)  하차  342   1637   1753   1856   2438   2425
# 2       2016-01-01  1   시청(151)  승차  103    127    110    191    298    582
# 3       2016-01-01  1   시청(151)  하차   68    306    554    939    689    665
# 4       2016-01-01  1   종각(152)  승차  702    341    234    296    335    419
# ...            ... ..       ...  ..  ...    ...    ...    ...    ...    ...
# 204369  2021-12-31  8        수진  하차   25     75     96    340    180    179
# 204370  2021-12-31  8        모란  승차   44    102    279    391    187    178
# 204371  2021-12-31  8        모란  하차   20     96    120    311    132    143
# 204372  2021-12-31  8       남위례  승차   20     83    279    347    138    186
# 204373  2021-12-31  8       남위례  하차   10     41    119    375    147     76
#
# ...

# %%
import re

# %%
pattern = r'\([\d]*\)'
df['역명']=df['역명'].apply(lambda x: re.sub(pattern=pattern, repl='', string= x))

# %%
df
# Out:
#                 날짜 호선   역명  구분  ~06  06~07  07~08  08~09  09~10  10~11  ...  \
# 0       2016-01-01  1  서울역  승차  469    339    584   1144   1723   2087  ...
# 1       2016-01-01  1  서울역  하차  342   1637   1753   1856   2438   2425  ...
# 2       2016-01-01  1   시청  승차  103    127    110    191    298    582  ...
# 3       2016-01-01  1   시청  하차   68    306    554    939    689    665  ...
# 4       2016-01-01  1   종각  승차  702    341    234    296    335    419  ...
# ...            ... ..  ...  ..  ...    ...    ...    ...    ...    ...  ...
# 204369  2021-12-31  8   수진  하차   25     75     96    340    180    179  ...
# 204370  2021-12-31  8   모란  승차   44    102    279    391    187    178  ...
# 204371  2021-12-31  8   모란  하차   20     96    120    311    132    143  ...
# 204372  2021-12-31  8  남위례  승차   20     83    279    347    138    186  ...
# 204373  2021-12-31  8  남위례  하차   10     41    119    375    147     76  ...
#
# ...

# %%
df.to_csv('서울교통공사_1_8호선일별역별시간대별승하차인원_(2016~2021년).csv', index=False)
