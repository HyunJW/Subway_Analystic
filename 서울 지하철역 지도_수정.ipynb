# %%
import pandas as pd
import folium
import json
import numpy as np
import requests

# %%
# df_trans=pd.read_csv('./연평균 지하철 이용객.csv')

# %%
# # kakao key 불러오기
# with open('C:/workspace/api_key/kakao_key.txt') as file:
#     kakao_key = file.read()

# # kakao_key를 통해서 모든 지하철역 주소 위도 경도 좌표 구하기
# url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
# header = {"Authorization": "KakaoAK " + kakao_key}
# addr, lngs, lats = [], [], []
# for i in range(len(df_trans)):
#     query = df_trans['지하철역'][i]
#     if '역' not in df_trans['지하철역'][i]:
#         station = df_trans['지하철역'][i]
#         if '(' in df_trans['지하철역'][i]:
#             station = df_trans['지하철역'][i].split('(')[0]
#         query = station + '역'
#     result = requests.get(url, params = {'query':query}, headers={'Authorization' : 'KakaoAK ' + kakao_key}).json()['documents']
#     try:
#         addr.append(result[0]['address_name'])
#         lngs.append(float(result[0]['x']))
#         lats.append(float(result[0]['y']))
#     except:
#         print(df_trans['지하철역'][i])

# %%
# df_trans['주소'] = pd.DataFrame(addr)
# df_trans['위도'] = pd.DataFrame(lats)
# df_trans['경도'] = pd.DataFrame(lngs)

# %%
# df_trans_seoul = df_trans[df_trans['주소'].str.contains('서울')]

# %%
# df_trans_seoul.set_index('지하철역', inplace=True)

# %%
# df_trans_seoul.reset_index(inplace=True)

# %%
# df_trans_seoul.to_csv('seoul_stations.csv', index=False)

# %%
df_trans_seoul=pd.read_csv('./seoul_stations.csv')

# %%
df_trans_seoul.head(2)
# Out:
#       지하철역  호선명  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  가산디지털단지  1호선       1340.00      6.133333   8205.400000   1980.583333
# 1       개봉  1호선       1226.05      8.633333  18414.966667   5494.800000
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  07시-08시 하차인원  ...  1시이후 승차  \
# 0   7914.766667  10941.750000      14763.35  46802.533333  ...      0.7
# 1  36569.333333  11855.966667      95251.20  16530.883333  ...      0.3
#
#     1시이후 하차         총 이용객         유임승차인원         무임승차인원     유임하차인원  \
# 0  2.033333  9.784055e+05  418268.766667   29773.750000  497380.25
# 1  2.283333  1.322553e+06  514742.366667  145080.383333  511793.65
#
#           무임하차인원                주소         위도          경도
# 0   32982.716667  서울 금천구 가산동 468-4  37.480396  126.882662
# 1  150936.250000    서울 구로구 개봉동 415  37.494642  126.858716
#
# [2 rows x 54 columns]

# %%
df_map=pd.concat([df_trans_seoul.iloc[:,:2],df_trans_seoul.iloc[:,-3:]], axis=1)

# %%
df_map
# Out:
#              지하철역  호선명                  주소         위도          경도
# 0         가산디지털단지  1호선    서울 금천구 가산동 468-4  37.480396  126.882662
# 1              개봉  1호선      서울 구로구 개봉동 415  37.494642  126.858716
# 2             광운대  1호선       서울 노원구 월계동 85  37.623837  127.061695
# 3              구로  1호선    서울 구로구 구로동 585-3  37.503342  126.882308
# 4              구일  1호선   서울 구로구 구로동 636-45  37.496255  126.869691
# ..            ...  ...                 ...        ...         ...
# 372            응봉  중앙선      서울 성동구 응봉동 246  37.549953  127.034484
# 373   이촌(국립중앙박물관)  중앙선    서울 용산구 이촌동 17-69  37.522413  126.973544
# 374            중랑  중앙선     서울 중랑구 중화동 73-7  37.594843  127.075680
# 375  청량리(서울시립대입구)  중앙선  서울 동대문구 전농동 591-53  37.580733  127.048504
# 376            한남  중앙선    서울 용산구 한남동 399-7  37.529429  127.009209
#
# [377 rows x 5 columns]

# %%
# 환승 가능한 역들
df_tran=[]
for i in df_trans_seoul['지하철역'].unique():
    index = df_trans_seoul[df_trans_seoul['지하철역'] == i].index
    if len(df_trans_seoul[df_trans_seoul['지하철역'] == i]) > 1:
        for j in index:
            df_tran.append(df_trans_seoul.iloc[j])
    else:
        pass

# %%
df_tran=pd.concat([pd.DataFrame(df_tran).iloc[:,:2],pd.DataFrame(df_tran).iloc[:,-3:]], axis=1)

# %%
df_tran=df_tran.groupby(['지하철역', '주소','위도','경도']).sum().reset_index()

# %%
df_tran
# Out:
#           지하철역                   주소         위도          경도             호선명
# 0         가락시장    서울 송파구 가락동 184-23  37.493099  127.118263          3호선8호선
# 1      가산디지털단지     서울 금천구 가산동 468-4  37.480396  126.882662          1호선7호선
# 2         강남구청    서울 강남구 삼성동 111-44  37.517216  127.041311          7호선분당선
# 3         건대입구       서울 광진구 화양동 7-3  37.540408  127.069203          2호선7호선
# 4        고속터미널     서울 서초구 반포동 19-11  37.504549  127.005121       3호선7호선9호선
# ..         ...                  ...        ...         ...             ...
# 63  충정로(경기대입구)  서울 서대문구 충정로3가 319-1  37.559763  126.964492          2호선5호선
# 64        태릉입구     서울 노원구 공릉동 616-4  37.618460  127.075405          6호선7호선
# 65          합정       서울 마포구 서교동 393  37.549913  126.914454          2호선6호선
# 66        홍대입구       서울 마포구 동교동 165  37.556871  126.923779  2호선경의선공항철도 1호선
# 67       효창공원앞        서울 용산구 효창동 80  37.539309  126.961398          6호선경의선
#
# [68 rows x 5 columns]

# %%
#  01~09호선 분리
df_map_1=df_map[df_map['호선명']=='1호선']
df_map_2=df_map[df_map['호선명']=='2호선']
df_map_3=df_map[df_map['호선명']=='3호선']
df_map_4=df_map[df_map['호선명']=='4호선']
df_map_5=df_map[df_map['호선명']=='5호선']
df_map_6=df_map[df_map['호선명']=='6호선']
df_map_7=df_map[df_map['호선명']=='7호선']
df_map_8=df_map[df_map['호선명']=='8호선']
df_map_9=df_map[df_map['호선명']=='9호선']
df_map_10=df_map[df_map['호선명']=='경의선']
df_map_11=df_map[df_map['호선명']=='경춘선']
df_map_12=df_map[df_map['호선명']=='공항철도 1호선']
df_map_13=df_map[df_map['호선명']=='분당선']
df_map_14=df_map[df_map['호선명']=='우이신설선']
df_map_15=df_map[df_map['호선명']=='중앙선']

# %%
candidate=pd.read_csv('./환승역 후보.csv')

# %%
candidate
# Out:
#             지하철역 환승가능여부       출근시간대 승차       출근시간대 하차       퇴근시간대 승차  \
# 0            학여울      N   11743.666667   18536.500000   18563.200000
# 1             반포      N   29552.116667   51668.016667   48592.333333
# 2      녹사평(용산구청)      N   21001.133333   34967.350000   47723.966667
# 3     월드컵경기장(성산)      N   25702.850000   28018.416667   45758.116667
# 4            서울숲      N   51952.283333   62128.166667   75630.316667
# 5             언주      N   22171.966667   97975.600000   97481.450000
# 6     봉화산(서울의료원)      N  113918.250000   25789.866667   31708.766667
# 7             일원      N   59327.933333   67197.550000   54308.916667
# 8          영등포시장      N   52103.700000   70814.866667   77604.600000
# 9           여의나루      N   19209.816667  106458.083333  122446.900000
# 10   공릉(서울과학기술대)      N  105727.733333   54639.600000   62904.183333
# 11           수락산      N  133213.566667   43366.233333   55772.500000
# 12          상왕십리      N  128909.516667   67385.383333   72190.100000
# 13            강동      N  183715.850000   90114.566667  108194.850000
# 14            논현      N   41065.616667  261155.283333  208474.966667
# 15            청담      N   41856.433333  314077.066667  227509.233333
# 16   경복궁(정부서울청사)      N   57811.666667  230447.366667  225597.516667
# 17            안국      N   26037.116667  274596.416667  269722.400000
# 18   오목교(목동운동장앞)      N  139248.916667  160058.266667  169119.200000
# 19     회현(남대문시장)      N   28313.100000  304034.433333  293064.650000
# 20  남부터미널(예술의전당)      N  108930.433333  312847.816667  315726.016667
# 21    강변(동서울터미널)      N  310965.850000  137473.333333  218915.200000
#
#          퇴근시간대 하차         유임이용객          무임이용객         총 이용객  유임이용객 비율  \
# 0    11735.283333  1.157779e+05   28751.666667  1.445295e+05     0.801
# 1    30374.183333  2.903113e+05   59744.133333  3.500554e+05     0.829
# 2    47658.150000  3.184402e+05   36007.016667  3.544472e+05     0.898
# 3    41734.216667  2.656673e+05  109136.500000  3.748038e+05     0.709
# 4    52836.433333  4.411345e+05   46166.383333  4.873009e+05     0.905
# 5    35592.850000  4.454473e+05   46779.466667  4.922268e+05     0.905
# 6    80241.983333  4.146879e+05   94950.266667  5.096382e+05     0.814
# 7    50060.300000  4.129607e+05  111298.350000  5.242591e+05     0.788
# 8    57533.450000  4.067348e+05  135583.166667  5.423179e+05     0.750
# 9    72300.366667  5.960562e+05   53620.650000  6.496769e+05     0.917
# 10  102831.933333  5.814463e+05  127188.783333  7.086351e+05     0.821
# 11  113194.183333  5.931634e+05  170000.416667  7.631638e+05     0.777
# 12  108467.350000  6.414789e+05  124748.116667  7.662270e+05     0.837
# 13  133021.516667  8.656845e+05  180396.150000  1.046081e+06     0.828
# 14   89646.283333  1.035277e+06   95508.133333  1.130785e+06     0.916
# 15   64166.883333  1.031620e+06  133631.383333  1.165252e+06     0.885
# 16   95122.000000  1.154223e+06  162846.900000  1.317069e+06     0.876
# 17   68796.766667  1.147111e+06  197556.583333  1.344668e+06     0.853
# 18  191894.733333  1.232900e+06  156258.450000  1.389159e+06     0.888
# 19   61529.416667  1.245850e+06  361258.166667  1.607108e+06     0.775
# 20  179654.566667  1.648329e+06  230358.416667  1.878687e+06     0.877
# 21  335019.900000  2.096152e+06  248150.700000  2.344303e+06     0.894
#
#     무임이용객 비율       면적  층수
# 0      0.199  28768.4   6
# 1      0.171  12401.8   3
# 2      0.102  10677.6   5
# 3      0.291  12286.2   3
# 4      0.095  20369.0   4
# 5      0.095  11552.8   5
# 6      0.186  20369.0   4
# 7      0.212  10573.0   3
# 8      0.250  13407.2   6
# 9      0.083  10598.9   5
# 10     0.179  20369.0   4
# 11     0.223  10488.2   3
# 12     0.163  25983.4   7
# 13     0.172  18984.6   4
# 14     0.084  11834.6   3
# 15     0.115  20302.8   4
# 16     0.124  20369.0   4
# 17     0.147  11076.6   3
# 18     0.112  12405.2   3
# 19     0.225  12024.8   4
# 20     0.123  14336.5   3
# 21     0.106  20369.0   4

# %%
candidate_location=[]
for i in range(0,len(candidate['지하철역'])):
    candidate_location=pd.concat([pd.DataFrame(candidate_location),df_map[df_map['지하철역']==candidate['지하철역'][i]]], axis=0)

# %%
candidate_location=candidate_location.reset_index()
candidate_location.drop(columns='index', inplace=True)

# %%
candidate_location
# Out:
#             지하철역  호선명                    주소         위도          경도
# 0            학여울  3호선      서울 강남구 대치동 514-3  37.496885  127.071167
# 1             반포  7호선        서울 서초구 잠원동 103  37.508161  127.011586
# 2      녹사평(용산구청)  6호선        서울 용산구 용산동4가 4  37.534723  126.986550
# 3     월드컵경기장(성산)  6호선        서울 마포구 성산동 420  37.569636  126.899098
# 4            서울숲  분당선  서울 성동구 성수동1가 656-436  37.543646  127.044746
# 5             언주  9호선    서울 강남구 논현동 279-165  37.507335  127.033971
# 6     봉화산(서울의료원)  6호선      서울 중랑구 신내동 643-1  37.617351  127.091360
# 7             일원  3호선        서울 강남구 일원동 717  37.483989  127.084130
# 8          영등포시장  5호선   서울 영등포구 영등포동5가 62-1  37.522709  126.905180
# 9           여의나루  5호선     서울 영등포구 여의도동 84-4  37.527147  126.932986
# 10   공릉(서울과학기술대)  7호선      서울 노원구 공릉동 385-4  37.625543  127.073034
# 11           수락산  7호선     서울 노원구 상계동 1132-9  37.677881  127.055351
# 12          상왕십리  2호선   서울 성동구 하왕십리동 946-14  37.564437  127.029272
# 13            강동  5호선        서울 강동구 천호동 447  37.535882  127.132396
# 14            논현  7호선     서울 강남구 논현동 279-67  37.511200  127.021654
# 15            청담  7호선      서울 강남구 청담동 77-76  37.519456  127.053718
# 16   경복궁(정부서울청사)  3호선       서울 종로구 적선동 81-1  37.575806  126.973691
# 17            안국  3호선       서울 종로구 안국동 73-1  37.576502  126.985421
# 18   오목교(목동운동장앞)  5호선      서울 양천구 목동 406-30  37.524534  126.875307
# 19     회현(남대문시장)  4호선        서울 중구 남창동 64-1  37.558761  126.978437
# 20  남부터미널(예술의전당)  3호선    서울 서초구 서초동 1748-30  37.485200  127.016200
# 21    강변(동서울터미널)  2호선      서울 광진구 구의동 546-6  37.535118  127.094741

# %%
# # 환승 후보역 지도에 표시
# for i in candidate_location.index: 
#     folium.Marker(
#         radius=200, 
#         location=[candidate_location.위도[i],candidate_location.경도[i]],
#         popup=folium.Popup(candidate_location.호선명[i], max_width=200),
#         tooltip=candidate_location.지하철역[i]+'(환승후보역)',
#         color='yellow',
#         icon = folium.Icon(
#         icon='train-subway')
#     ).add_to(map)

# %%
map=folium.Map(location=[df_map.위도.mean(),df_map.경도.mean()], zoom_start=11,
               tiles='Stamen Terrain') 

r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

map.choropleth(geo_data=seoul_geo,
             line_color='black',
             fill_opacity=0.1,
             line_opacity=1,
             line_weight=2
            )

colors=['darkblue','darkgreen','darkorange','darkturquoise','slateblue','chocolate','olive',
      'deeppink','tan','mediumaquamarine','forestgreen','dodgeblue','gold','yellogreen','mediumaquamarine']


# 환승 후보역 지도에 표시
for i in candidate_location.index: 
    folium.Marker(
        radius=1000, 
        location=[candidate_location.위도[i],candidate_location.경도[i]],
        popup=folium.Popup(candidate_location.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        icon = folium.Icon(
            color='purple',
            icon='train-subway',
            prefix='fa'
        )
    ).add_to(map)
for i in candidate_location.index: 
    folium.Circle(
        radius=2000, 
        location=[candidate_location.위도[i],candidate_location.경도[i]],
        popup=folium.Popup(candidate_location.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        color='red',
        fill=True,
        fill_opacity=0.2,
        fill_color='red'
    ).add_to(map)

for i in range(1,16):
    for j in globals()[f'df_map_{i}'].index:
        folium.Circle(
        radius=200, 
        location=[globals()[f'df_map_{i}'].위도[j],globals()[f'df_map_{i}'].경도[j]],
        popup=folium.Popup(globals()[f'df_map_{i}'].호선명[j], max_width=200),
        tooltip=globals()[f'df_map_{i}'].지하철역[j],
        color=colors[i-1],
        fill=True,
        fill_color=colors[i-1]
    ).add_to(map)

for i in df_tran.index: 
    folium.Circle(
        radius=200, 
        location=[df_tran.위도[i],df_tran.경도[i]],
        popup=folium.Popup(df_tran.호선명[i], max_width=200),
        tooltip=df_tran.지하철역[i]+'(환승가능역)',
        color='red',
        fill=True,
        fill_opacity=1,
        fill_color='red'
    ).add_to(map)
    

    
title='<h3 align="center" style="font-size:20px">서울시 지하철 노선</h3>'
map.get_root().html.add_child(folium.Element(title))

map
# Out:
# C:\Users\user\anaconda3\lib\site-packages\folium\folium.py:465: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a51857e046ed933bd39447a74164559 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;서울시 지하철 노선&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a51857e046ed933bd39447a74164559&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a51857e046ed933bd39447a74164559 = L.map(
#                 &quot;map_1a51857e046ed933bd39447a74164559&quot;,
#                 {
#                     center: [37.54924965398841, 126.9973837852767],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11a838cdc2612c0cfa75fe3a3e1cae69 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a51857e046ed933bd39447a74164559);
#
#
#             var choropleth_a2dc44452f9d93e36185d0da550562ec = L.featureGroup(
#                 {}
#             ).addTo(map_1a51857e046ed933bd39447a74164559);
#
#
#         function geo_json_3858f50c8e33c404eb6e17e7dbba4129_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_3858f50c8e33c404eb6e17e7dbba4129_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3858f50c8e33c404eb6e17e7dbba4129 = L.geoJson(null, {
#                 onEachFeature: geo_json_3858f50c8e33c404eb6e17e7dbba4129_onEachFeature,
#
#                 style: geo_json_3858f50c8e33c404eb6e17e7dbba4129_styler,
#         });
#
#         function geo_json_3858f50c8e33c404eb6e17e7dbba4129_add (data) {
#             geo_json_3858f50c8e33c404eb6e17e7dbba4129
#                 .addData(data)
#                 .addTo(choropleth_a2dc44452f9d93e36185d0da550562ec);
#         }
#             geo_json_3858f50c8e33c404eb6e17e7dbba4129_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.

# %% [markdown]
# ## 환승 후보역 추리기

# %%
from geopy import distance

# %%
df_map=df_map.groupby(['지하철역', '주소','위도','경도']).sum().reset_index()

# %%
df_map.loc[df_map[df_map['지하철역'] == '용산'].index, '호선명'] = '1호선중앙선'

# %%
df_map.loc[df_map[df_map['지하철역'] == '왕십리(성동구청)'].index, '호선명'] = '2호선5호선중앙선분당선'

# %%
df_map[df_map['지하철역'] == '왕십리(성동구청)']
# Out:
#           지하철역              주소         위도          경도           호선명
# 225  왕십리(성동구청)  서울 성동구 행당동 192  37.561268  127.037103  2호선5호선중앙선분당선

# %%
## STEP 1 ##

map=folium.Map(location=[df_map.위도.mean(),df_map.경도.mean()], zoom_start=11,
               tiles='Stamen Terrain') 

r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

map.choropleth(geo_data=seoul_geo,
             line_color='black',
             fill_opacity=0.1,
             line_opacity=1,
             line_weight=2
            )

colors=['darkblue','darkgreen','darkorange','darkturquoise','slateblue','chocolate','olive',
      'deeppink','tan','mediumaquamarine','forestgreen','dodgeblue','gold','yellogreen','mediumaquamarine']


for i in range(1,16):
    for j in globals()[f'df_map_{i}'].index:
        folium.Circle(
        radius=200, 
        location=[globals()[f'df_map_{i}'].위도[j],globals()[f'df_map_{i}'].경도[j]],
        popup=folium.Popup(globals()[f'df_map_{i}'].호선명[j], max_width=200),
        tooltip=globals()[f'df_map_{i}'].지하철역[j],
        color=colors[i-1],
        fill=True,
        fill_color=colors[i-1]
    ).add_to(map)

for i in df_tran.index: 
    folium.Circle(
        radius=200, 
        location=[df_tran.위도[i],df_tran.경도[i]],
        popup=folium.Popup(df_tran.호선명[i], max_width=200),
        tooltip=df_tran.지하철역[i]+'(환승가능역)',
        color='gray',
        fill=True,
        fill_opacity=1,
        fill_color='darkgray'
    ).add_to(map)
    

    
title='<h3 align="center" style="font-size:30px">STEP 1: 현재 서울 내 운행 중인 지하철 표시</h3>'
map.get_root().html.add_child(folium.Element(title))

map
# Out:
# C:\Users\user\anaconda3\lib\site-packages\folium\folium.py:465: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2a4f05c4fd8e692e5c69bb4099c52fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:30px&quot;&gt;STEP 1: 현재 서울 내 운행 중인 지하철 표시&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2a4f05c4fd8e692e5c69bb4099c52fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2a4f05c4fd8e692e5c69bb4099c52fb = L.map(
#                 &quot;map_c2a4f05c4fd8e692e5c69bb4099c52fb&quot;,
#                 {
#                     center: [37.54948895240268, 126.99918561725433],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cd2900a36cd59b2ac16375dcf42122a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c2a4f05c4fd8e692e5c69bb4099c52fb);
#
#
#             var choropleth_c557ff2919716039eaee6b85016ffed1 = L.featureGroup(
#                 {}
#             ).addTo(map_c2a4f05c4fd8e692e5c69bb4099c52fb);
#
#
#         function geo_json_58e45b08e9f65fa7129257f0423d485e_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_58e45b08e9f65fa7129257f0423d485e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_58e45b08e9f65fa7129257f0423d485e = L.geoJson(null, {
#                 onEachFeature: geo_json_58e45b08e9f65fa7129257f0423d485e_onEachFeature,
#
#                 style: geo_json_58e45b08e9f65fa7129257f0423d485e_styler,
#         });
#
#         function geo_json_58e45b08e9f65fa7129257f0423d485e_add (data) {
#             geo_json_58e45b08e9f65fa7129257f0423d485e
#                 .addData(data)
#                 .addTo(choropleth_c557ff2919716039eaee6b85016ffed1);
#         }
#             geo_json_58e45b08e9f65fa7129257f0423d485e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.5248

# %%
## STEP 2 ##

map=folium.Map(location=[df_map.위도.mean(),df_map.경도.mean()], zoom_start=11,
               tiles='Stamen Terrain') 

r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

map.choropleth(geo_data=seoul_geo,
             line_color='black',
             fill_opacity=0.1,
             line_opacity=1,
             line_weight=2
            )

colors=['darkblue','darkgreen','darkorange','darkturquoise','slateblue','chocolate','olive',
      'deeppink','tan','mediumaquamarine','forestgreen','dodgeblue','gold','yellogreen','mediumaquamarine']

# 환승 후보역 지도에 표시
for i in candidate_location.index: 
    folium.Marker(
        radius=1000, 
        location=[candidate_location.위도[i],candidate_location.경도[i]],
        popup=folium.Popup(candidate_location.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        icon = folium.Icon(
            color='purple',
            icon='train-subway',
            prefix='fa'
        )
    ).add_to(map)
for i in candidate_location.index: 
    folium.Circle(
        radius=2300, 
        location=[candidate_location.위도[i],candidate_location.경도[i]],
        popup=folium.Popup(candidate_location.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        color='red',
        fill=True,
        fill_opacity=0.2,
        fill_color='red'
    ).add_to(map)
    
for i in range(1,16):
    for j in globals()[f'df_map_{i}'].index:
        folium.Circle(
        radius=200, 
        location=[globals()[f'df_map_{i}'].위도[j],globals()[f'df_map_{i}'].경도[j]],
        popup=folium.Popup(globals()[f'df_map_{i}'].호선명[j], max_width=200),
        tooltip=globals()[f'df_map_{i}'].지하철역[j],
        color=colors[i-1],
        fill=True,
        fill_color=colors[i-1]
    ).add_to(map)

for i in df_tran.index: 
    folium.Circle(
        radius=200, 
        location=[df_tran.위도[i],df_tran.경도[i]],
        popup=folium.Popup(df_tran.호선명[i], max_width=200),
        tooltip=df_tran.지하철역[i]+'(환승가능역)',
        color='gray',
        fill=True,
        fill_opacity=1,
        fill_color='darkgray'
    ).add_to(map)
    

    
title='<h3 align="center" style="font-size:30px">STEP 2: 환승 후보역 반경 2.3km 표시</h3>'
map.get_root().html.add_child(folium.Element(title))

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56d2d380e92785a0893606df26554186 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:30px&quot;&gt;STEP 2: 환승 후보역 반경 2.3km 표시&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56d2d380e92785a0893606df26554186&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56d2d380e92785a0893606df26554186 = L.map(
#                 &quot;map_56d2d380e92785a0893606df26554186&quot;,
#                 {
#                     center: [37.54948895240268, 126.99918561725433],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c19f06ce270303c434271260dafb653 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56d2d380e92785a0893606df26554186);
#
#
#             var choropleth_0abbcddbb4524ea563a8629182940740 = L.featureGroup(
#                 {}
#             ).addTo(map_56d2d380e92785a0893606df26554186);
#
#
#         function geo_json_413acef785c8b4583f4f89fdb2a92dac_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_413acef785c8b4583f4f89fdb2a92dac_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_413acef785c8b4583f4f89fdb2a92dac = L.geoJson(null, {
#                 onEachFeature: geo_json_413acef785c8b4583f4f89fdb2a92dac_onEachFeature,
#
#                 style: geo_json_413acef785c8b4583f4f89fdb2a92dac_styler,
#         });
#
#         function geo_json_413acef785c8b4583f4f89fdb2a92dac_add (data) {
#             geo_json_413acef785c8b4583f4f89fdb2a92dac
#                 .addData(data)
#                 .addTo(choropleth_0abbcddbb4524ea563a8629182940740);
#         }
#             geo_json_413acef785c8b4583f4f89fdb2a92dac_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841

# %%
def creat_cand(can_gps, df_map, km):
    cand = []
    for i in df_map.index:
        map_gps = df_map.loc[i, '위도'],df_map.loc[i, '경도']
        dist = distance.distance(can_gps, map_gps).km
        if (dist < km) & (dist > 0):
            cand.append(df_map.loc[i])
    return pd.DataFrame(cand)

# %%
ca=[]
for i in candidate_location.index:
    km = 2.3
    can_gps = candidate_location.loc[i, '위도'],candidate_location.loc[i, '경도']
    ca.append(creat_cand(can_gps, df_map, km))

# %%
## STEP 3 ##

map=folium.Map(location=[df_map.위도.mean(),df_map.경도.mean()], zoom_start=11,
               tiles='Stamen Terrain') 

r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

map.choropleth(geo_data=seoul_geo,
             line_color='black',
             fill_opacity=0.1,
             line_opacity=1,
             line_weight=2
            )

# 환승 후보역 지도에 표시
for i in candidate_location.index: 
    folium.Marker(
        radius=1000, 
        location=[candidate_location.위도[i],candidate_location.경도[i]],
        popup=folium.Popup(candidate_location.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        icon = folium.Icon(
            color='purple',
            icon='train-subway',
            prefix='fa'
        )
    ).add_to(map)
    
for i in candidate_location.index: 
    folium.Circle(
        radius=2300, 
        location=[candidate_location.위도[i],candidate_location.경도[i]],
        popup=folium.Popup(candidate_location.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        color='red',
        fill=True,
        fill_opacity=0.2,
        fill_color='red'
    ).add_to(map)
    
for i in range(0,len(ca)):
    for j in ca[i].index:
        folium.Circle(
        radius=200, 
        location=[ca[i].위도[j],ca[i].경도[j]],
        popup=folium.Popup(ca[i].호선명[j], max_width=200),
        tooltip=ca[i].지하철역[j],
        color='yellow',
        fill=True,
        fill_color='yellow'
    ).add_to(map)
    
    
title='<h3 align="center" style="font-size:30px">STEP 3: 환승 후보역 반경 2.3km 외 역 삭제</h3>'
map.get_root().html.add_child(folium.Element(title))

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50cebe09c395d77472557a77c479fbf7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:30px&quot;&gt;STEP 3: 환승 후보역 반경 2.3km 외 역 삭제&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50cebe09c395d77472557a77c479fbf7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50cebe09c395d77472557a77c479fbf7 = L.map(
#                 &quot;map_50cebe09c395d77472557a77c479fbf7&quot;,
#                 {
#                     center: [37.54948895240268, 126.99918561725433],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e48880a750bf788f9a9c898f13409bd = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_50cebe09c395d77472557a77c479fbf7);
#
#
#             var choropleth_398f191280314da10a458ae1e2504da8 = L.featureGroup(
#                 {}
#             ).addTo(map_50cebe09c395d77472557a77c479fbf7);
#
#
#         function geo_json_c5adbf0d58c04f3e5eeef776fcab3e08_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_c5adbf0d58c04f3e5eeef776fcab3e08_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c5adbf0d58c04f3e5eeef776fcab3e08 = L.geoJson(null, {
#                 onEachFeature: geo_json_c5adbf0d58c04f3e5eeef776fcab3e08_onEachFeature,
#
#                 style: geo_json_c5adbf0d58c04f3e5eeef776fcab3e08_styler,
#         });
#
#         function geo_json_c5adbf0d58c04f3e5eeef776fcab3e08_add (data) {
#             geo_json_c5adbf0d58c04f3e5eeef776fcab3e08
#                 .addData(data)
#                 .addTo(choropleth_398f191280314da10a458ae1e2504da8);
#         }
#             geo_json_c5adbf0d58c04f3e5eeef776fcab3e08_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.52

# %%
def store_line(lines, line):
    if len(line) > 0:
        line = line.split('선')[0:-1]
        for li in line:
            li = li + '선'
            if li not in lines:
                lines.append(li)
    return lines

# %%
def store_lines(lines, candidate_station, cand):
    for i in cand.index:
        # 같은호선인 환승역들의 환승노선 저장
        if candidate_station['호선명'] in cand.loc[i, '호선명']:
            line = cand.loc[i, '호선명'].replace(candidate_station['호선명'], '')
            lines = store_line(lines, line)

        # 제거할 다른 노선 환승역의 환승노선 저장
        else:
            for li in lines:
                if li in cand.loc[i, '호선명']:
                    line = cand.loc[i, '호선명'].replace(li, '')
                    lines = store_line(lines, line)
    return lines

# %%
def remove_cand(cand, lines):
    for i in cand.index:
        if cand.loc[i, '호선명'].count('선') > 1:
            cand.drop(index=i, inplace=True)
        else:
            for line in lines:
                if line in cand.loc[i, '호선명']:
                    cand.drop(index=i, inplace=True)
                    break
    return cand

# %%
candidate_location_copy = candidate_location.copy()
candidate_name = []

# %%
choice = pd.DataFrame(columns=['지하철역', '주소', '위도', '경도', '호선명', '후보역'])
for i in candidate_location.index:
#for i in range(14,15):
    km = 2.3
    can_gps = candidate_location.loc[i, '위도'],candidate_location.loc[i, '경도']
    cand = creat_cand(can_gps, df_map, km)
    lines = [candidate_location.loc[i]['호선명']]
    candidate_station = candidate_location.loc[i]
    for j in range(3):
        lines = store_lines(lines, candidate_station, cand)
    cand = remove_cand(cand, lines)
    
    if len(cand) == 0:
        candidate_location_copy.drop(index=i, inplace=True)
    else:
        choice = pd.concat([choice, cand])
        for k in range(len(cand)):
            candidate_name.append(candidate_location.loc[i, '지하철역'])

# %%
choice['후보역'] = candidate_name

# %%
choice
# Out:
#               지하철역                  주소         위도          경도  호선명  \
# 186             신사      서울 강남구 신사동 667  37.516436  127.020309  3호선
# 200            압구정      서울 강남구 신사동 668  37.526491  127.028509  3호선
# 248             잠원    서울 서초구 잠원동 100-1  37.512890  127.011419  3호선
# 98              망우      서울 중랑구 상봉동 172  37.599296  127.092367  중앙선
# 136             삼전      서울 송파구 잠실동 347  37.504549  127.087364  9호선
# 30         광흥창(서강)   서울 마포구 창전동 145-17  37.547486  126.932030  6호선
# 64             당고개      서울 노원구 상계동 111  37.670217  127.079067  4호선
# 103             명동   서울 중구 충무로2가 109-2  37.560965  126.986402  4호선
# 293      회현(남대문시장)      서울 중구 남창동 64-1  37.558761  126.978437  4호선
# 157            선유도  서울 영등포구 양평동5가 66-1  37.538159  126.893334  9호선
# 183            신목동     서울 양천구 목동 136-2  37.544288  126.883096  9호선
# 55              내방   서울 서초구 방배동 874-16  37.487659  126.993600  7호선
# 130             사평    서울 서초구 반포동 128-7  37.504233  127.015272  9호선
# 27        광나루(장신대)      서울 광진구 광장동 237  37.545299  127.103521  5호선
# 195  아차산(어린이대공원후문)    서울 광진구 능동 256-16  37.552249  127.089565  5호선
# 208    어린이대공원(세종대)    서울 광진구 화양동 164-1  37.547961  127.074655  7호선
#
#               후보역
# 186            언주
# 200            언주
# 248            언주
# 98     봉화산(서울의료원)
# 136            일원
# 30           여의나루
# 64            수락산
# 103   경복궁(정부서울청사)
# 293   경복궁(정부서울청사)
# 157   오목교(목동운동장앞)
# 183   오목교(목동운동장앞)
# 55   남부터미널(예술의전당)
# 130  남부터미널(예술의전당)
# 27     강변(동서울터미널)
# 195    강변(동서울터미널)
# 208    강변(동서울터미널)

# %%
candidate_location_copy
# Out:
#             지하철역  호선명                  주소         위도          경도
# 5             언주  9호선  서울 강남구 논현동 279-165  37.507335  127.033971
# 6     봉화산(서울의료원)  6호선    서울 중랑구 신내동 643-1  37.617351  127.091360
# 7             일원  3호선      서울 강남구 일원동 717  37.483989  127.084130
# 9           여의나루  5호선   서울 영등포구 여의도동 84-4  37.527147  126.932986
# 11           수락산  7호선   서울 노원구 상계동 1132-9  37.677881  127.055351
# 16   경복궁(정부서울청사)  3호선     서울 종로구 적선동 81-1  37.575806  126.973691
# 18   오목교(목동운동장앞)  5호선    서울 양천구 목동 406-30  37.524534  126.875307
# 20  남부터미널(예술의전당)  3호선  서울 서초구 서초동 1748-30  37.485200  127.016200
# 21    강변(동서울터미널)  2호선    서울 광진구 구의동 546-6  37.535118  127.094741

# %%
## STEP 4 ##

map=folium.Map(location=[df_map.위도.mean(),df_map.경도.mean()], zoom_start=11,
               tiles='Stamen Terrain') 

r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

map.choropleth(geo_data=seoul_geo,
             line_color='black',
             fill_opacity=0.1,
             line_opacity=1,
             line_weight=2
            )

# 환승 후보역 지도에 표시
for i in candidate_location.index: 
    folium.Marker(
        radius=1000, 
        location=[candidate_location.위도[i],candidate_location.경도[i]],
        popup=folium.Popup(candidate_location.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        icon = folium.Icon(
            color='purple',
            icon='train-subway',
            prefix='fa'
        )
    ).add_to(map)
    
for i in candidate_location.index: 
    folium.Circle(
        radius=2300, 
        location=[candidate_location.위도[i],candidate_location.경도[i]],
        popup=folium.Popup(candidate_location.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        color='red',
        fill=True,
        fill_opacity=0.2,
        fill_color='red'
    ).add_to(map)
    

for i in choice.index:
    folium.Circle(
    radius=200, 
    location=[choice.위도[i],choice.경도[i]],
    popup=folium.Popup(choice.호선명[i], max_width=200),
    tooltip=choice.지하철역[i],
    color='yellow',
    fill=True,
    fill_color='yellow'
).add_to(map)
    
    
title='<h3 align="center" style="font-size:25px">STEP 4: 환승 후보역과 같은 호선 또는 근처 환승역과 노선이 중복되는 역 삭제</h3>'
map.get_root().html.add_child(folium.Element(title))

map
# Out:
# C:\Users\user\anaconda3\lib\site-packages\folium\folium.py:465: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aebff0dd80f3f7154da8a98e013e8360 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:25px&quot;&gt;STEP 4: 환승 후보역과 같은 호선 또는 근처 환승역과 노선이 중복되는 역 삭제&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aebff0dd80f3f7154da8a98e013e8360&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aebff0dd80f3f7154da8a98e013e8360 = L.map(
#                 &quot;map_aebff0dd80f3f7154da8a98e013e8360&quot;,
#                 {
#                     center: [37.54948895240268, 126.99918561725433],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35f91bdc7f7f8edb932d20430ac937b4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aebff0dd80f3f7154da8a98e013e8360);
#
#
#             var choropleth_0b8858998c8a2a30aaa2aa7eb4b2605e = L.featureGroup(
#                 {}
#             ).addTo(map_aebff0dd80f3f7154da8a98e013e8360);
#
#
#         function geo_json_c0e42eff465ded0f754cbd39d0092179_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_c0e42eff465ded0f754cbd39d0092179_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c0e42eff465ded0f754cbd39d0092179 = L.geoJson(null, {
#                 onEachFeature: geo_json_c0e42eff465ded0f754cbd39d0092179_onEachFeature,
#
#                 style: geo_json_c0e42eff465ded0f754cbd39d0092179_styler,
#         });
#
#         function geo_json_c0e42eff465ded0f754cbd39d0092179_add (data) {
#             geo_json_c0e42eff465ded0f754cbd39d0092179
#                 .addData(data)
#                 .addTo(choropleth_0b8858998c8a2a30aaa2aa7eb4b2605e);
#         }
#             geo_json_c0e42eff465ded0f754cbd39d0092179_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087

# %%
## STEP 5 ##

map=folium.Map(location=[df_map.위도.mean(),df_map.경도.mean()], zoom_start=11,
               tiles='Stamen Terrain') 

r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

map.choropleth(geo_data=seoul_geo,
             line_color='black',
             fill_opacity=0.1,
             line_opacity=1,
             line_weight=2
            )

# 환승 후보역 지도에 표시
for i in candidate_location_copy.index: 
    folium.Marker(
        radius=1000, 
        location=[candidate_location_copy.위도[i],candidate_location_copy.경도[i]],
        popup=folium.Popup(candidate_location_copy.호선명[i], max_width=200),
        tooltip=candidate_location.지하철역[i]+'(환승후보역)',
        icon = folium.Icon(
            color='purple',
            icon='train-subway',
            prefix='fa'
        )
    ).add_to(map)
    
for i in candidate_location_copy.index: 
    folium.Circle(
        radius=2300, 
        location=[candidate_location_copy.위도[i],candidate_location_copy.경도[i]],
        popup=folium.Popup(candidate_location_copy.호선명[i], max_width=200),
        tooltip=candidate_location_copy.지하철역[i]+'(환승후보역)',
        color='red',
        fill=True,
        fill_opacity=0.2,
        fill_color='red'
    ).add_to(map)
    

for i in choice.index:
    folium.Circle(
    radius=200, 
    location=[choice.위도[i],choice.경도[i]],
    popup=folium.Popup(choice.호선명[i], max_width=200),
    tooltip=choice.지하철역[i],
    color='yellow',
    fill=True,
    fill_color='yellow'
).add_to(map)
    
    
title='<h3 align="center" style="font-size:30px">STEP 5: 최종 환승 후보 역 </h3>'
map.get_root().html.add_child(folium.Element(title))

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c44ec0e7fc083aac946a13e9521279f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:30px&quot;&gt;STEP 5: 최종 환승 후보 역 &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c44ec0e7fc083aac946a13e9521279f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c44ec0e7fc083aac946a13e9521279f0 = L.map(
#                 &quot;map_c44ec0e7fc083aac946a13e9521279f0&quot;,
#                 {
#                     center: [37.54948895240268, 126.99918561725433],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d63250676e86ecfc7914b850054c6ebc = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c44ec0e7fc083aac946a13e9521279f0);
#
#
#             var choropleth_09a9e19077efcabef8c80c371eb8e87b = L.featureGroup(
#                 {}
#             ).addTo(map_c44ec0e7fc083aac946a13e9521279f0);
#
#
#         function geo_json_5fdb013992b003e1cf5aca08e28fa8a6_styler(feature) {
#             switch(feature.properties.code) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;opacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_5fdb013992b003e1cf5aca08e28fa8a6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5fdb013992b003e1cf5aca08e28fa8a6 = L.geoJson(null, {
#                 onEachFeature: geo_json_5fdb013992b003e1cf5aca08e28fa8a6_onEachFeature,
#
#                 style: geo_json_5fdb013992b003e1cf5aca08e28fa8a6_styler,
#         });
#
#         function geo_json_5fdb013992b003e1cf5aca08e28fa8a6_add (data) {
#             geo_json_5fdb013992b003e1cf5aca08e28fa8a6
#                 .addData(data)
#                 .addTo(choropleth_09a9e19077efcabef8c80c371eb8e87b);
#         }
#             geo_json_5fdb013992b003e1cf5aca08e28fa8a6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.5248412201670

# %%
# 인근 5개역 중 환승역과 같은 노선이 있으면 환승 후보역과 연결하는 역에서 탈락
for i in candidate_location_copy.index:
    station = candidate_location_copy.loc[i]
    cand_lines = choice[choice['후보역'] == station['지하철역']]['호선명'].unique()
    lines = []
    km = 5.75
    can_gps = station.loc['위도'], station.loc['경도']
    for j in df_map.index:
        map_gps = df_map.loc[j, '위도'],df_map.loc[j, '경도']
        dist = distance.distance(can_gps, map_gps).km
        if (dist < km) & (dist > 0) & (station['호선명'] in df_map.loc[j, '호선명']):
            for line in cand_lines:
                if line in df_map.loc[j, '호선명']:
                    for li in line.split('선')[:-1]:
                        if li not in station['호선명']:
                            lines.append(li + '선')
    if len(lines) > 0:
        for l in lines:
            index = choice[(choice['후보역'] == station['지하철역']) & (choice['호선명'] == l)].index
            choice.drop(index=index, inplace=True)

# %%
index = []
for i in choice['후보역'].unique():
    index.append(candidate_location_copy[candidate_location_copy['지하철역'] == i].index[0])
candidate_location_copy = candidate_location_copy.loc[index]

# %%
candidate_location_copy
# Out:
#           지하철역  호선명                주소         위도          경도
# 6   봉화산(서울의료원)  6호선  서울 중랑구 신내동 643-1  37.617351  127.091360
# 7           일원  3호선    서울 강남구 일원동 717  37.483989  127.084130
# 21  강변(동서울터미널)  2호선  서울 광진구 구의동 546-6  37.535118  127.094741

# %%
choice
# Out:
#               지하철역                주소         위도          경도  호선명         후보역
# 98              망우    서울 중랑구 상봉동 172  37.599296  127.092367  중앙선  봉화산(서울의료원)
# 136             삼전    서울 송파구 잠실동 347  37.504549  127.087364  9호선          일원
# 27        광나루(장신대)    서울 광진구 광장동 237  37.545299  127.103521  5호선  강변(동서울터미널)
# 195  아차산(어린이대공원후문)  서울 광진구 능동 256-16  37.552249  127.089565  5호선  강변(동서울터미널)

# %%
station = candidate_location_copy.loc[21]
can_gps = station['위도'], station['경도']
dist = []
for j in choice[choice['후보역'] == station['지하철역']].index:
    choice_gps = choice.loc[j, '위도'], choice.loc[j, '경도']
    dist.append((choice.loc[j, '지하철역'], distance.distance(can_gps, choice_gps).km))

# %%
dist
# Out:
# [('광나루(장신대)', 1.3707735502825125), ('아차산(어린이대공원후문)', 1.9555999213542004)]
